# %% [markdown]
# # Stage 1: Scan Simulation/Rendering
#
# ## Initialization and imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import mako
import os
sys.path.append("/home/sebastian/Projects/SRB/Package/repo/scanner-sim")
#source(mitsuba_path + "/setpath.sh") TODO this should happen from outside
os.chdir("/home/sebastian/Projects/SRB/Package/repo/scanner-sim")

# %%
from simulator.rendering import *

data_path = "data"

# Create camera and projector config
config = configure_all(calib_path=os.path.join(data_path, "calibrations"),
                       obj_geom=os.path.join(data_path, "calibrations", "object", "shapes.json"),
                       cam_quarter_res=True)

# Edit object config
config["obj_file"] = os.path.join(data_path, "objects", "machined", "shapes.obj")
config["obj_type"] = "obj"
config["cam_samples"] = 64

# Prepare patterns
patterns = prepare_patterns(config, 
                            os.path.join(data_path, "patterns", "gray"),
                            os.path.join(data_path, "calibrations", "projector", "projector_geometry.json"),
                            os.path.join(data_path, "calibrations", "projector", "vignetting.png"),
                            scale4x=False, overwrite=True)

for cnt, pattern in enumerate(patterns):
    config["pro_pattern_file"] = pattern
    write_scene_file(config, 
                     os.path.join(data_path, "results", "test", "pattern_%02i.xml"%cnt), 
                     os.path.join(data_path, "scenes", "scene_default.xml"))
    
render_scenes(os.path.join(data_path, "results", "test", "pattern_*.xml"), verbose=True)
# Out:
# Scene 1 of 46: data/results/test/pattern_00.xml
# 2021-12-09 18:34:25 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:34:25 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_00.xml" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:34:25 INFO  main [BitmapTexture] Loading texture "img_00_calib.png"
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:34:25 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:34:25 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:34:25 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:34:25 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:34:25 INFO  main [TriMesh] Done after 107 ms (mesh now has 76228 vertices)
# 2021-12-09 18:34:25 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:34:25 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:34:25 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 379 ms)
# 2021-12-09 18:34:25 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:34:26 INFO  ren0 [KDTreeBase] Finished -- took 532 ms.
# 2021-12-09 18:34:26 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:34:26 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:34:26 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 59.7s)
# Rendering: [+                                           ] (2.0s, ETA: 46.8s)
# Rendering: [+++                                         ] (3.0s, ETA: 36.5s)
# Rendering: [++++                                        ] (4.1s, ETA: 33.8s)
# Rendering: [++++++                                      ] (5.1s, ETA: 30.7s)
# Rendering: [+++++++                                     ] (6.1s, ETA: 27.8s)
# Rendering: [++++++++++                                  ] (7.1s, ETA: 23.9s)
# Rendering: [+++++++++++++                               ] (8.1s, ETA: 18.1s)
# Rendering: [++++++++++++++++                            ] (9.1s, ETA: 14.8s)
# Rendering: [++++++++++++++++++++                        ] (10.1s, ETA: 11.2s)
# Rendering: [+++++++++++++++++++++++++                   ] (11.1s, ETA: 7.7s)
# Rendering: [+++++++++++++++++++++++++++++++             ] (12.1s, ETA: 4.8s)
# Rendering: [++++++++++++++++++++++++++++++++++++        ] (13.1s, ETA: 2.5s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++  ] (14.1s, ETA: 0.4s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++++] (14.3s, ETA: 0.0s)
# 2021-12-09 18:34:40 INFO  ren0 [RenderJob] Render time: 14.9000s
# 2021-12-09 18:34:40 INFO  ren0 [HDRFilm] Writing image to "/home/sebastian/Projects/SRB/Package/repo/scanner-sim/data/results/test/pattern_00.exr" ..
# 2021-12-09 18:34:40 INFO  main [statistics.cpp:142] Statistics:
# ------------------------------------------------------------
#  * Loaded plugins :
#     -  plugins/bitmap.so [Bitmap texture]
#     -  plugins/box.so [Box filter]
#     -  plugins/constant.so [Constant background emitter]
#     -  plugins/diffuse.so [Smooth diffuse BRDF]
#     -  plugins/disk.so [Disk intersection primitive]
#     -  plugins/field.so [Field extraction integrator]
#     -  plugins/halton.so [Halton QMC sampler]
#     -  plugins/hdrfilm.so [High dynamic range film]
#     -  plugins/lanczos.so [Lanczos Sinc filter]
#     -  plugins/multichannel.so [Multi-channel integrator]
#     -  plugins/obj.so [OBJ triangle mesh loader]
#     -  plugins/path.so [MI path tracer]
#     -  plugins/roughplastic.so [Rough plastic BRDF]
#     -  plugins/sphere.so [Sphere intersection primitive]
#     -  plugins/spot.so [Spot light]
#     -  plugins/thinlens.so [Perspective thin lens camera]
#
#   * General :
#     -  Normal rays traced : 156.732 M
#     -  Shadow rays traced : 31.313 M
#
#   * Path tracer :
#     -  Average path length : 1.09 (136.59 M / 125.45 M)
#
#   * Texture system :
#     -  Cumulative MIP map memory allocations : 3.955 MiB
#     -  Filtered texture lookups : 0.00 % (0.00 of 26.09 M)
# ------------------------------------------------------------
#
# Scene 2 of 46: data/results/test/pattern_01.xml
# 2021-12-09 18:34:40 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:34:40 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_01.xml" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:34:40 INFO  main [BitmapTexture] Loading texture "img_01_calib.png"
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:34:40 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:34:40 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:34:40 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:34:40 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:34:41 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:34:41 INFO  main [TriMesh] Done after 106 ms (mesh now has 76228 vertices)
# 2021-12-09 18:34:41 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:34:41 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:34:41 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 350 ms)
# 2021-12-09 18:34:41 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:34:41 INFO  ren0 [KDTreeBase] Finished -- took 518 ms.
# 2021-12-09 18:34:41 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:34:41 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:34:41 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 52.9s)
# Rendering: [+                                           ] (2.0s, ETA: 44.3s)
# Rendering: [+++                                         ] (3.0s, ETA: 36.9s)
# Rendering: [++++                                        ] (4.1s, ETA: 34.0s)
# Rendering: [++++++                                      ] (5.1s, ETA: 31.0s)
# Rendering: [+++++++                                     ] (6.1s, ETA: 27.8s)
# Rendering: [++++++++++                                  ] (7.1s, ETA: 23.9s)
# Rendering: [+++++++++++++                               ] (8.1s, ETA: 18.3s)
# Rendering: [++++++++++++++++                            ] (9.1s, ETA: 14.9s)
# Rendering: [++++++++++++++++++++                        ] (10.1s, ETA: 11.3s)
# Rendering: [+++++++++++++++++++++++++                   ] (11.1s, ETA: 7.8s)
# Rendering: [+++++++++++++++++++++++++++++++             ] (12.2s, ETA: 4.9s)
# Rendering: [++++++++++++++++++++++++++++++++++++        ] (13.2s, ETA: 2.7s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++  ] (14.2s, ETA: 0.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++++] (14.4s, ETA: 0.0s)
# 2021-12-09 18:34:56 INFO  ren0 [RenderJob] Render time: 14.9980s
# 2021-12-09 18:34:56 INFO  ren0 [HDRFilm] Writing image to "/home/sebastian/Projects/SRB/Package/repo/scanner-sim/data/results/test/pattern_01.exr" ..
# 2021-12-09 18:34:56 INFO  main [statistics.cpp:142] Statistics:
# ------------------------------------------------------------
#  * Loaded plugins :
#     -  plugins/bitmap.so [Bitmap texture]
#     -  plugins/box.so [Box filter]
#     -  plugins/constant.so [Constant background emitter]
#     -  plugins/diffuse.so [Smooth diffuse BRDF]
#     -  plugins/disk.so [Disk intersection primitive]
#     -  plugins/field.so [Field extraction integrator]
#     -  plugins/halton.so [Halton QMC sampler]
#     -  plugins/hdrfilm.so [High dynamic range film]
#     -  plugins/lanczos.so [Lanczos Sinc filter]
#     -  plugins/multichannel.so [Multi-channel integrator]
#     -  plugins/obj.so [OBJ triangle mesh loader]
#     -  plugins/path.so [MI path tracer]
#     -  plugins/roughplastic.so [Rough plastic BRDF]
#     -  plugins/sphere.so [Sphere intersection primitive]
#     -  plugins/spot.so [Spot light]
#     -  plugins/thinlens.so [Perspective thin lens camera]
#
#   * General :
#     -  Normal rays traced : 156.733 M
#     -  Shadow rays traced : 31.315 M
#
#   * Path tracer :
#     -  Average path length : 1.09 (136.59 M / 125.45 M)
#
#   * Texture system :
#     -  Cumulative MIP map memory allocations : 3.955 MiB
#     -  Filtered texture lookups : 0.00 % (0.00 of 26.09 M)
# ------------------------------------------------------------
#
# Scene 3 of 46: data/results/test/pattern_02.xml
# 2021-12-09 18:34:56 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:34:56 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_02.xml" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:34:56 INFO  main [BitmapTexture] Loading texture "img_02_calib.png"
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:34:56 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:34:56 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:34:56 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:34:56 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:34:56 INFO  main [TriMesh] Done after 120 ms (mesh now has 76228 vertices)
# 2021-12-09 18:34:56 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:34:56 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:34:56 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 370 ms)
# 2021-12-09 18:34:56 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:34:57 INFO  ren0 [KDTreeBase] Finished -- took 514 ms.
# 2021-12-09 18:34:57 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:34:57 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:34:57 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 1.1m)
# Rendering: [+                                           ] (2.0s, ETA: 52.1s)
# Rendering: [+++                                         ] (3.1s, ETA: 38.9s)
# Rendering: [++++                                        ] (4.1s, ETA: 34.6s)
# Rendering: [++++++                                      ] (5.2s, ETA: 31.5s)
# Rendering: [+++++++                                     ] (6.2s, ETA: 28.6s)
# Rendering: [+++++++++                                   ] (7.2s, ETA: 25.1s)
# Rendering: [++++++++++++                                ] (8.2s, ETA: 19.7s)
# Rendering: [++++++++++++++++                            ] (9.2s, ETA: 16.0s)
# Rendering: [+++++++++++++++++++                         ] (10.2s, ETA: 12.7s)
# Rendering: [++++++++++++++++++++++++                    ] (11.2s, ETA: 8.9s)
# Rendering: [++++++++++++++++++++++++++++++              ] (12.2s, ETA: 5.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++         ] (13.2s, ETA: 3.2s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++    ] (14.2s, ETA: 1.2s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++++] (14.7s, ETA: 0.0s)
# 2021-12-09 18:35:12 INFO  ren0 [RenderJob] Render time: 15.3050s
# 2021-12-09 18:35:12 INFO  ren0 [HDRFilm] Writing image to "/home/sebastian/Projects/SRB/Package/repo/scanner-sim/data/results/test/pattern_02.exr" ..
# 2021-12-09 18:35:12 INFO  main [statistics.cpp:142] Statistics:
# ------------------------------------------------------------
#  * Loaded plugins :
#     -  plugins/bitmap.so [Bitmap texture]
#     -  plugins/box.so [Box filter]
#     -  plugins/constant.so [Constant background emitter]
#     -  plugins/diffuse.so [Smooth diffuse BRDF]
#     -  plugins/disk.so [Disk intersection primitive]
#     -  plugins/field.so [Field extraction integrator]
#     -  plugins/halton.so [Halton QMC sampler]
#     -  plugins/hdrfilm.so [High dynamic range film]
#     -  plugins/lanczos.so [Lanczos Sinc filter]
#     -  plugins/multichannel.so [Multi-channel integrator]
#     -  plugins/obj.so [OBJ triangle mesh loader]
#     -  plugins/path.so [MI path tracer]
#     -  plugins/roughplastic.so [Rough plastic BRDF]
#     -  plugins/sphere.so [Sphere intersection primitive]
#     -  plugins/spot.so [Spot light]
#     -  plugins/thinlens.so [Perspective thin lens camera]
#
#   * General :
#     -  Normal rays traced : 156.730 M
#     -  Shadow rays traced : 31.312 M
#
#   * Path tracer :
#     -  Average path length : 1.09 (136.59 M / 125.45 M)
#
#   * Texture system :
#     -  Cumulative MIP map memory allocations : 3.955 MiB
#     -  Filtered texture lookups : 0.00 % (0.00 of 26.09 M)
# ------------------------------------------------------------
#
# Scene 4 of 46: data/results/test/pattern_03.xml
# 2021-12-09 18:35:12 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:35:12 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_03.xml" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:35:12 INFO  main [BitmapTexture] Loading texture "img_03_calib.png"
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:35:12 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:35:12 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:35:12 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:35:12 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:35:12 INFO  main [TriMesh] Done after 104 ms (mesh now has 76228 vertices)
# 2021-12-09 18:35:12 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:35:12 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:35:12 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 347 ms)
# 2021-12-09 18:35:12 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:35:13 INFO  ren0 [KDTreeBase] Finished -- took 514 ms.
# 2021-12-09 18:35:13 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:35:13 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:35:13 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 54.5s)
# Rendering: [+                                           ] (2.0s, ETA: 44.3s)
# Rendering: [+++                                         ] (3.1s, ETA: 36.7s)
# Rendering: [++++                                        ] (4.1s, ETA: 33.8s)
# Rendering: [++++++                                      ] (5.1s, ETA: 30.8s)
# Rendering: [+++++++                                     ] (6.1s, ETA: 28.1s)
# Rendering: [+++++++++                                   ] (7.1s, ETA: 25.1s)
# Rendering: [++++++++++++                                ] (8.1s, ETA: 19.9s)
# Rendering: [++++++++++++++++                            ] (9.1s, ETA: 15.8s)
# Rendering: [++++++++++++++++++++                        ] (10.1s, ETA: 12.2s)
# Rendering: [+++++++++++++++++++++++++                   ] (11.1s, ETA: 8.4s)
# Rendering: [++++++++++++++++++++++++++++++              ] (12.1s, ETA: 5.3s)
# Rendering: [++++++++++++++++++++++++++++++++++++        ] (13.1s, ETA: 2.9s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++   ] (14.1s, ETA: 0.9s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++++] (14.5s, ETA: 0.0s)
# 2021-12-09 18:35:27 INFO  ren0 [RenderJob] Render time: 15.0970s
# 2021-12-09 18:35:27 INFO  ren0 [HDRFilm] Writing image to "/home/sebastian/Projects/SRB/Package/repo/scanner-sim/data/results/test/pattern_03.exr" ..
# 2021-12-09 18:35:27 INFO  main [statistics.cpp:142] Statistics:
# ------------------------------------------------------------
#  * Loaded plugins :
#     -  plugins/bitmap.so [Bitmap texture]
#     -  plugins/box.so [Box filter]
#     -  plugins/constant.so [Constant background emitter]
#     -  plugins/diffuse.so [Smooth diffuse BRDF]
#     -  plugins/disk.so [Disk intersection primitive]
#     -  plugins/field.so [Field extraction integrator]
#     -  plugins/halton.so [Halton QMC sampler]
#     -  plugins/hdrfilm.so [High dynamic range film]
#     -  plugins/lanczos.so [Lanczos Sinc filter]
#     -  plugins/multichannel.so [Multi-channel integrator]
#     -  plugins/obj.so [OBJ triangle mesh loader]
#     -  plugins/path.so [MI path tracer]
#     -  plugins/roughplastic.so [Rough plastic BRDF]
#     -  plugins/sphere.so [Sphere intersection primitive]
#     -  plugins/spot.so [Spot light]
#     -  plugins/thinlens.so [Perspective thin lens camera]
#
#   * General :
#     -  Normal rays traced : 156.734 M
#     -  Shadow rays traced : 31.316 M
#
#   * Path tracer :
#     -  Average path length : 1.09 (136.59 M / 125.45 M)
#
#   * Texture system :
#     -  Cumulative MIP map memory allocations : 3.955 MiB
#     -  Filtered texture lookups : 0.00 % (0.00 of 26.10 M)
# ------------------------------------------------------------
#
# Scene 5 of 46: data/results/test/pattern_04.xml
# 2021-12-09 18:35:27 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:35:27 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_04.xml" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:35:27 INFO  main [BitmapTexture] Loading texture "img_04_calib.png"
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:35:27 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:35:27 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:35:28 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:35:28 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:35:28 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:35:28 INFO  main [TriMesh] Done after 107 ms (mesh now has 76228 vertices)
# 2021-12-09 18:35:28 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:35:28 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:35:28 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 356 ms)
# 2021-12-09 18:35:28 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:35:28 INFO  ren0 [KDTreeBase] Finished -- took 525 ms.
# 2021-12-09 18:35:28 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:35:28 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:35:28 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 54.5s)
# Rendering: [+                                           ] (2.0s, ETA: 45.0s)
# Rendering: [+++                                         ] (3.0s, ETA: 36.2s)
# Rendering: [++++                                        ] (4.0s, ETA: 33.4s)
# Rendering: [++++++                                      ] (5.0s, ETA: 30.4s)
# Rendering: [+++++++                                     ] (6.0s, ETA: 27.5s)
# Rendering: [++++++++++                                  ] (7.1s, ETA: 23.6s)
# Rendering: [+++++++++++++                               ] (8.1s, ETA: 18.0s)
# Rendering: [+++++++++++++++++                           ] (9.1s, ETA: 14.4s)
# Rendering: [+++++++++++++++++++++                       ] (10.1s, ETA: 10.9s)
# Rendering: [++++++++++++++++++++++++++                  ] (11.2s, ETA: 7.4s)
# Rendering: [+++++++++++++++++++++++++++++++             ] (12.2s, ETA: 4.6s)
# Rendering: [+++++++++++++++++++++++++++++++++++++       ] (13.2s, ETA: 2.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++ ] (14.2s, ETA: 0.3s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++++] (14.3s, ETA: 0.0s)
# 2021-12-09 18:35:43 INFO  ren0 [RenderJob] Render time: 14.8800s
# 2021-12-09 18:35:43 INFO  ren0 [HDRFilm] Writing image to "/home/sebastian/Projects/SRB/Package/repo/scanner-sim/data/results/test/pattern_04.exr" ..
# 2021-12-09 18:35:43 INFO  main [statistics.cpp:142] Statistics:
# ------------------------------------------------------------
#  * Loaded plugins :
#     -  plugins/bitmap.so [Bitmap texture]
#     -  plugins/box.so [Box filter]
#     -  plugins/constant.so [Constant background emitter]
#     -  plugins/diffuse.so [Smooth diffuse BRDF]
#     -  plugins/disk.so [Disk intersection primitive]
#     -  plugins/field.so [Field extraction integrator]
#     -  plugins/halton.so [Halton QMC sampler]
#     -  plugins/hdrfilm.so [High dynamic range film]
#     -  plugins/lanczos.so [Lanczos Sinc filter]
#     -  plugins/multichannel.so [Multi-channel integrator]
#     -  plugins/obj.so [OBJ triangle mesh loader]
#     -  plugins/path.so [MI path tracer]
#     -  plugins/roughplastic.so [Rough plastic BRDF]
#     -  plugins/sphere.so [Sphere intersection primitive]
#     -  plugins/spot.so [Spot light]
#     -  plugins/thinlens.so [Perspective thin lens camera]
#
#   * General :
#     -  Normal rays traced : 156.730 M
#     -  Shadow rays traced : 31.312 M
#
#   * Path tracer :
#     -  Average path length : 1.09 (136.59 M / 125.45 M)
#
#   * Texture system :
#     -  Cumulative MIP map memory allocations : 3.955 MiB
#     -  Filtered texture lookups : 0.00 % (0.00 of 26.09 M)
# ------------------------------------------------------------
#
# Scene 6 of 46: data/results/test/pattern_05.xml
# 2021-12-09 18:35:43 INFO  main [mitsuba.cpp:275] Mitsuba version 0.6.0 (Linux, 64 bit), Copyright (c) 2017 Wenzel Jakob
# 2021-12-09 18:35:43 INFO  main [mitsuba.cpp:377] Parsing scene description from "data/results/test/pattern_05.xml" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/halton.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/box.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/hdrfilm.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/thinlens.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/path.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/field.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/multichannel.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/bitmap.so" ..
# 2021-12-09 18:35:43 INFO  main [BitmapTexture] Loading texture "img_05_calib.png"
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/lanczos.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/spot.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/constant.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/roughplastic.so" ..
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/obj.so" ..
# 2021-12-09 18:35:43 INFO  main [WavefrontOBJ] Loading geometry from "shapes.obj" ..
# 2021-12-09 18:35:43 INFO  main [WavefrontOBJ] shapes: 117590 triangles, 58783 vertices (merged 293987 vertices).
# 2021-12-09 18:35:43 INFO  main [TriMesh] Rebuilding the topology of "shapes" (117590 triangles, 58783 vertices, max. angle = 30.000000)
# 2021-12-09 18:35:43 WARN  main [TriMesh] Mesh contains 8 degenerate triangles!
# 2021-12-09 18:35:43 INFO  main [TriMesh] Done after 105 ms (mesh now has 76228 vertices)
# 2021-12-09 18:35:43 INFO  main [PluginManager] Loading plugin "plugins/diffuse.so" ..
# 2021-12-09 18:35:43 WARN  main [TriMesh] "shapes": Unable to generate 16 vertex normals
# 2021-12-09 18:35:43 INFO  main [WavefrontOBJ] Done with "shapes.obj" (took 348 ms)
# 2021-12-09 18:35:43 INFO  ren0 [KDTreeBase] Constructing a SAH kd-tree (117590 primitives) ..
# 2021-12-09 18:35:44 INFO  ren0 [KDTreeBase] Finished -- took 534 ms.
# 2021-12-09 18:35:44 INFO  ren0 [PluginManager] Loading plugin "plugins/disk.so" ..
# 2021-12-09 18:35:44 INFO  ren0 [PluginManager] Loading plugin "plugins/sphere.so" ..
# 2021-12-09 18:35:44 INFO  ren0 [MultiChannelIntegrator] Starting render job (1616x1213, 64 samples, 12 cores, SSE2 enabled) ..
#
# Rendering: [                                            ] (1.0s, ETA: 1.0m)
# Rendering: [+                                           ] (2.0s, ETA: 49.4s)
# Rendering: [+++                                         ] (3.0s, ETA: 37.3s)
# Rendering: [++++                                        ] (4.1s, ETA: 33.7s)
# Rendering: [++++++                                      ] (5.1s, ETA: 30.7s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e83857dbed8d> in <module>
#      26                      os.path.join(data_path, "scenes", "scene_default.xml"))
#      27
# ---> 28 render_scenes(os.path.join(data_path, "results", "test", "pattern_*.xml"), verbose=True)
#
# ~/Projects/SRB/Package/repo/scanner-sim/simulator/rendering/rendering.py in render_scenes(filenames_template, output_folder, verbose)
#      51         proc = subprocess.Popen(["mitsuba", *output, scene], stdout=subprocess.PIPE, universal_newlines=True)
#      52
# ---> 53         for line in proc.stdout:
#      54             if verbose:
#      55                 print(line[:-1])
#
# KeyboardInterrupt:

# %%
import os
import json
from IPython.display import Image
import matplotlib.pyplot as plt

#os.chdir("/sls/scanner-sim")
from rendering import render_object, generate_render_parameters

def save_config_and_run_scan(config_name, config):
    # Store rendering parameters for reference
    with open(config_name, "w") as fi:
        json.dump(config, fi, indent=2, sort_keys=True)  
    
    # Run render job which takes roughly 10 minutes to finish all images of the scan
    render_object(config_name)

# %% [markdown]
# ## Rendering an object with default Gray code patterns
#
# As a first step, we need to define the parameters for the simulation/renderer. This is done with the *generate_render_parameters()* function which supports many different settings. In this example, let's choose the shapes object.

# %%
pars = generate_render_parameters(obj_path="objects/machined/shapes.obj", # Path to the object (relative to the data folder)
                                  result_path="results/shapes", # Path where the results are stored
                                  typ="shapes", # Predefined settings for the shapes object to match the real scanner
                                  size="small", # Resolution of the renderings (large=original camera size, medium=original/2, small=original/4)
                                  samples=64, # Samples per pixel that are used for the rendering
                                  patterns="patterns/gray" # The patterns that are used for the scanning process
                                 )

# %% [markdown]
# This generates a parameter dictionary with default settings (matching the physical scanner) which can be subsequently modified if needed. The parameter dictionary is then stored and the simulation/rendering is started with the following code:

# %%
save_config_and_run_scan("data/configs/parameters_shapes.json", pars)

# %% [markdown]
# After rendering the images, let's look at some results...

# %%
Image(filename="data/results/shapes/img_016.png")

# %%
Image(filename="data/results/shapes/img_040.png")

# %% [markdown]
# ## Rendering an object with different light coding patterns
#
# In order to use different patterns, the path to the patterns and additional settings can be modified. The following example shows how to scan the pawn object with micro phase shifting patterns.

# %%
pars = generate_render_parameters(obj_path="objects/machined/pawn.obj", # The pawn object
                                  result_path="results/pawn", 
                                  typ="pawn",
                                  size="small",
                                  samples=64,
                                  cpu_count=8, # Render with only 8 cores this time
                                  patterns="patterns/mps/32-08", # Select micro phase shifting patterns
                                 )

pars["pattern_colored"] = False # We don't need support for colored patterns this time
pars["pattern_calibrate"] = True # Predistort the patterns so that they match the physical projector
pars["pattern_flip_ud"] = True # Flip the patterns vertically so that they are projected with an upright projector

save_config_and_run_scan("data/configs/parameters_pawn.json", pars)

# %%
Image(filename="data/results/pawn/img_000.png")

# %% [markdown]
# ## Rendering a colored/textured object (one single scan)
#
# Textured objects can be scanned/rendered similarly. Currently, only objects in *obj* format are supported. In this example, scan the object from only one direction.

# %%
pars = generate_render_parameters(obj_path="objects/colored/vase/vase.obj", 
                                  result_path="results/vase", 
                                  typ="vase", # Render with vase presets
                                  size="small",
                                  samples=64,
                                  cpu_count=8,
                                  patterns="patterns/gray"
                                 )

pars["pattern_colored"] = True

save_config_and_run_scan("data/configs/parameters_vase.json", pars)

# %% [markdown]
# Visualize the results again...

# %%
Image(filename="data/results/vase/img_018.png")

# %% [markdown]
# ## Rendering a colored/textured object (multiple scans, turntable)
#
# In this example, we scan the object from multiple directions to reproduce the full geometry. The object is rotated on a virtual turntable and all scans can be merged together in the reconstruction phase (see below). Note that this rendering process will take a while (~20 minutes).

# %%
pars = generate_render_parameters(obj_path="objects/colored/vase/vase.obj", 
                                  result_path="results/vase_full", 
                                  typ="vase", # Render with vase presets
                                  size="small",
                                  samples=32, # Let's reduce the samples for faster scanning
                                  cpu_count=8,
                                  patterns="patterns/gray"
                                 )

pars["pattern_colored"] = True
pars["rot_type"] = "Turntable" # Enable turntable rotation
pars["rot_range"] = [0, 360, 4] # Rotate between 0 and 360 degrees in 4 steps

save_config_and_run_scan("data/configs/parameters_vase_full.json", pars)

# %% [markdown]
# Let's see the 4 different views...

# %%
fig, axs = plt.subplots(1, 4, figsize=(20,15))
for i in range(4):
    img = plt.imread("data/results/vase_full/rot_%03i/img_000.png"%i)
    axs[i].imshow(img)
    axs[i].axis('off')

# %% [markdown]
# # Stage 2: Decoding and Reconstruction
#
# Attention: This stage depends on the results that were produced in stage 1. If you haven't run the relevant cells above, some cells will not work.
#
# ## Initialization and imports

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import glob
import json
from tqdm.auto import tqdm

#os.chdir("/sls/scanner-sim")
import meshplot as mp
from decoding import decode_gray, decode_mps
from reconstruction import reconstruct_single, merge_single
from utils import load_projector_calibration, load_camera_calibration, numpinize, load_openexr

# %% [markdown]
# ## Decoding of a single scan (shapes object with Gray code)

# %%
data_path = "data/results/shapes"

# Decode Gray coded images
idx_h, idx_v = decode_gray(data_path, group=True, plot=True, sim=True, threshold=130)

# %% [markdown]
# ## Reconstruction of a single scan (shapes object with Gray code)
#
# In this example, we reconstruct the depth map and the colored point cloud from the correspondence indices that were created during the decoding stage. The indices from the decoding stage don't need to be passed into the function, they are passed as files with configured filenames. In addition, we need to load the projector and camera calibration for the reconstruction.

# %%
# Load projector and camera calibration
pro_calib = load_projector_calibration("data/calibrations/projector_calibration_new.json")[2]
cam_calib = load_camera_calibration("data/calibrations/camera_calibration_s_new.json")

data_path = "data/results/shapes"

points, colors, depth_map = reconstruct_single(data_path, cam_calib, pro_calib, plot=True, sim=True)

# %% [markdown]
# How does the reconstructed depthmap compare to the ground truth depth map? For this we load the ground truth depth map from the renderings and plot the difference and a histogram over the difference.

# %%
img, gt_depth_map = load_openexr("data/results/shapes/img_000.exr", load_depth=True)
difference = gt_depth_map - depth_map
hist_difference = np.abs(difference.reshape(-1))

fig, axs = plt.subplots(1, 2, figsize=(20,7))
axs[0].imshow(difference)
axs[0].axis('off')
axs[1].hist(difference.reshape(-1), bins=np.linspace(0.00001, 0.002, 40))
plt.show()

# %% [markdown]
# Finally, let us also visualize the reconstructed point cloud...

# %%
mp.plot(points, c=colors, shading={"point_size": 5.0});

# %% [markdown]
# ## Decoding and reconstruction of multiple scans (vase object with Gray code)
#
# Similar to before, we can decode the multiple scans of the colored vase object.

# %%
# Load projector and camera calibration
pro_calib = load_projector_calibration("data/calibrations/projector_calibration_new.json")[2]
cam_calib = load_camera_calibration("data/calibrations/camera_calibration_s_new.json")

def decode_and_reconstruct(data_path):
    decode_gray(data_path, group=True, sim=True, threshold=50)
    reconstruct_single(data_path, cam_calib, pro_calib, sim=True)


data_paths = glob.glob("data/results/vase_full/rot_*")

for data_path in tqdm(data_paths):
    decode_and_reconstruct(data_path)

# %% [markdown]
# Now merge all the decoded and reconstructed scans together by rotating them to the same coordinate system.

# %%
# Load the turntable calib
stage_calib = numpinize(json.load(open("data/calibrations/stage_calibration_sim.json", "r")))

# Merge the single scans
points, normals, colors = merge_single("data/results/vase_full", "/rot_%s/reconstructed/group_points.ply"%"%03i",
                                     stage_calib, title="vase.ply", max_range=4, sim=True)
    
# Plot the reconstructed point cloud
mp.plot(points, c=colors, shading={"point_size": 5.0});

# %% [markdown]
# ## Decoding of different patterns (pawn with micro phase shifting)
#
# It is possible to use different patterns for the scanning proces. This can be achieved by adding the patterns as images and a decoding stage, which reads in the rendered results and produces the correspondence map. For the three decoding strategies listed in the paper, we supply an implementation with our software. The following example shows the decoding for micro phase shifting patterns.

# %%
ic_h = decode_mps("data/results/pawn", "data/patterns/mps/32-08/", cam=[1616, 1213])

plt.figure(figsize=(20, 10))
plt.imshow(ic_h)
plt.axis('off')
plt.show()
